# %%
# dependencies
from nba_api.stats.endpoints import teamestimatedmetrics
import requests
import json
import pandas as pd
import time
season_list = ['2017-18', '2018-19', '2019-20', '2020-21', '2021-22']
df = pd.DataFrame()

# %%
# go through each api response for respective season
response = teamestimatedmetrics.TeamEstimatedMetrics(
    league_id='00',
    season='2017-18',
    season_type='Regular Season',
    headers={'Accept': 'application/json, text/plain, */*',
'Accept-Encoding': 'gzip, deflate, br',
'Accept-Language': 'en-US,en;q=0.9',
'Connection': 'keep-alive',
'Host': 'stats.nba.com',
'Origin': 'https://www.nba.com',
'Referer': 'https://www.nba.com/',
'sec-ch-ua': '"Google Chrome";v="87", "\"Not;A\\Brand";v="99", "Chromium";v="87"',
'sec-ch-ua-mobile': '?1',
'Sec-Fetch-Dest': 'empty',
'Sec-Fetch-Mode': 'cors',
'Sec-Fetch-Site': 'same-site',
'User-Agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.141 Mobile Safari/537.36',
'x-nba-stats-origin': 'stats',
'x-nba-stats-token': 'true'})
df_1718 = response.get_data_frames()[0]
df_1718['Season'] = '2017-18'
# print (i , "completed", sep="---")  
df = df.append(df_1718, ignore_index=True)
# Out:
# C:\Users\Stephen\AppData\Local\Temp\ipykernel_43420\4250416056.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_1718, ignore_index=True)

# %%
# go through each api response for respective season
response = teamestimatedmetrics.TeamEstimatedMetrics(
    league_id='00',
    season='2018-19',
    season_type='Regular Season',
    headers={'Accept': 'application/json, text/plain, */*',
'Accept-Encoding': 'gzip, deflate, br',
'Accept-Language': 'en-US,en;q=0.9',
'Connection': 'keep-alive',
'Host': 'stats.nba.com',
'Origin': 'https://www.nba.com',
'Referer': 'https://www.nba.com/',
'sec-ch-ua': '"Google Chrome";v="87", "\"Not;A\\Brand";v="99", "Chromium";v="87"',
'sec-ch-ua-mobile': '?1',
'Sec-Fetch-Dest': 'empty',
'Sec-Fetch-Mode': 'cors',
'Sec-Fetch-Site': 'same-site',
'User-Agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.141 Mobile Safari/537.36',
'x-nba-stats-origin': 'stats',
'x-nba-stats-token': 'true'})
df_1819 = response.get_data_frames()[0]
df_1819['Season'] = '2018-19'
# print (i , "completed", sep="---")  
df = df.append(df_1819, ignore_index=True)
# Out:
# C:\Users\Stephen\AppData\Local\Temp\ipykernel_43420\1425289376.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_1819, ignore_index=True)

# %%
df.sort_values(by='Season', ascending=False)
# Out:
#                  TEAM_NAME     TEAM_ID  GP   W   L  W_PCT     MIN  \
# 30           Atlanta Hawks  1610612737  82  29  53  0.354  3971.0
# 45         New York Knicks  1610612752  82  17  65  0.207  3956.0
# 33        Sacramento Kings  1610612758  82  39  43  0.476  3946.0
# 34         Milwaukee Bucks  1610612749  82  60  22  0.732  3956.0
# 35   Oklahoma City Thunder  1610612760  82  49  33  0.598  3971.0
# 36             LA Clippers  1610612746  82  48  34  0.585  3966.0
# 37      Philadelphia 76ers  1610612755  82  51  31  0.622  3961.0
# 38      Washington Wizards  1610612764  82  32  50  0.390  3986.0
# 39           Brooklyn Nets  1610612751  82  42  40  0.512  3996.0
# 40   Golden State Warriors  1610612744  82  57  25  0.695  3961.0
# 41            Phoenix Suns  1610612756  82  19  63  0.232  3976.0
# 42  Minnesota Timberwolves  1610612750  82  36  46  0.439  3966.0
# 43               Utah Jazz  1610612762  82  50  32  0.610  3951.0
# ...

# %%
# go through each api response for respective season
response = teamestimatedmetrics.TeamEstimatedMetrics(
    league_id='00',
    season='2019-20',
    season_type='Regular Season',
    headers={'Accept': 'application/json, text/plain, */*',
'Accept-Encoding': 'gzip, deflate, br',
'Accept-Language': 'en-US,en;q=0.9',
'Connection': 'keep-alive',
'Host': 'stats.nba.com',
'Origin': 'https://www.nba.com',
'Referer': 'https://www.nba.com/',
'sec-ch-ua': '"Google Chrome";v="87", "\"Not;A\\Brand";v="99", "Chromium";v="87"',
'sec-ch-ua-mobile': '?1',
'Sec-Fetch-Dest': 'empty',
'Sec-Fetch-Mode': 'cors',
'Sec-Fetch-Site': 'same-site',
'User-Agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.141 Mobile Safari/537.36',
'x-nba-stats-origin': 'stats',
'x-nba-stats-token': 'true'})
df_1920 = response.get_data_frames()[0]
df_1920['Season'] = '2019-2020'
# print (i , "completed", sep="---")  
df = df.append(df_1920, ignore_index=True)
# Out:
# C:\Users\Stephen\AppData\Local\Temp\ipykernel_43420\3224910735.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_1920, ignore_index=True)

# %%
# go through each api response for respective season
response = teamestimatedmetrics.TeamEstimatedMetrics(
    league_id='00',
    season='2020-21',
    season_type='Regular Season',
    headers={'Accept': 'application/json, text/plain, */*',
'Accept-Encoding': 'gzip, deflate, br',
'Accept-Language': 'en-US,en;q=0.9',
'Connection': 'keep-alive',
'Host': 'stats.nba.com',
'Origin': 'https://www.nba.com',
'Referer': 'https://www.nba.com/',
'sec-ch-ua': '"Google Chrome";v="87", "\"Not;A\\Brand";v="99", "Chromium";v="87"',
'sec-ch-ua-mobile': '?1',
'Sec-Fetch-Dest': 'empty',
'Sec-Fetch-Mode': 'cors',
'Sec-Fetch-Site': 'same-site',
'User-Agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.141 Mobile Safari/537.36',
'x-nba-stats-origin': 'stats',
'x-nba-stats-token': 'true'})
df_2021 = response.get_data_frames()[0]
df_2021['Season'] = '2020-2021'
# print (i , "completed", sep="---")  
df = df.append(df_2021, ignore_index=True)
# Out:
# C:\Users\Stephen\AppData\Local\Temp\ipykernel_43420\2364516388.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_2021, ignore_index=True)

# %%
# go through each api response for respective season
response = teamestimatedmetrics.TeamEstimatedMetrics(
    league_id='00',
    season='2021-22',
    season_type='Regular Season',
    headers={'Accept': 'application/json, text/plain, */*',
'Accept-Encoding': 'gzip, deflate, br',
'Accept-Language': 'en-US,en;q=0.9',
'Connection': 'keep-alive',
'Host': 'stats.nba.com',
'Origin': 'https://www.nba.com',
'Referer': 'https://www.nba.com/',
'sec-ch-ua': '"Google Chrome";v="87", "\"Not;A\\Brand";v="99", "Chromium";v="87"',
'sec-ch-ua-mobile': '?1',
'Sec-Fetch-Dest': 'empty',
'Sec-Fetch-Mode': 'cors',
'Sec-Fetch-Site': 'same-site',
'User-Agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.141 Mobile Safari/537.36',
'x-nba-stats-origin': 'stats',
'x-nba-stats-token': 'true'})
df_2122 = response.get_data_frames()[0]
df_2122['Season'] = '2021-2022'
# print (i , "completed", sep="---")  
df = df.append(df_2122, ignore_index=True)
# Out:
# C:\Users\Stephen\AppData\Local\Temp\ipykernel_43420\369675501.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_2122, ignore_index=True)

# %%
df.to_csv('team_metrics.csv', index=False)

# %%
df.columns
# Out:
# Index(['TEAM_NAME', 'TEAM_ID', 'GP', 'W', 'L', 'W_PCT', 'MIN', 'E_OFF_RATING',
#        'E_DEF_RATING', 'E_NET_RATING', 'E_PACE', 'E_AST_RATIO', 'E_OREB_PCT',
#        'E_DREB_PCT', 'E_REB_PCT', 'E_TM_TOV_PCT', 'GP_RANK', 'W_RANK',
#        'L_RANK', 'W_PCT_RANK', 'MIN_RANK', 'E_OFF_RATING_RANK',
#        'E_DEF_RATING_RANK', 'E_NET_RATING_RANK', 'E_AST_RATIO_RANK',
#        'E_OREB_PCT_RANK', 'E_DREB_PCT_RANK', 'E_REB_PCT_RANK',
#        'E_TM_TOV_PCT_RANK', 'E_PACE_RANK', 'Season'],
#       dtype='object')

# %%
# group stats by team and print 
avg_team_metrics = df.groupby(['TEAM_NAME','TEAM_ID'])['W', 'L', 'W_PCT', 'MIN', 'E_OFF_RATING',\
       'E_DEF_RATING', 'E_NET_RATING', 'E_PACE', 'E_AST_RATIO', 'E_OREB_PCT',\
       'E_DREB_PCT', 'E_REB_PCT', 'E_TM_TOV_PCT'].mean()
avg_team_metrics
avg_team_metrics.to_csv('avg_team_metrics.csv', index=True)
# Out:
# C:\Users\Stephen\AppData\Local\Temp\ipykernel_43420\2206025165.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   avg_team_metrics = df.groupby(['TEAM_NAME','TEAM_ID'])['W', 'L', 'W_PCT', 'MIN', 'E_OFF_RATING',\
