# %%
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sqlalchemy import create_engine
import psycopg2

# %%
password = 'Techbobcats=0618'
#your postgresql db
engine = create_engine(f'postgresql://postgres:{password}@localhost/NBA')

# %%
df = pd.read_sql_query('Select * from public."Games"', con = engine)
df
# Out:
#       SEASON_ID     TEAM_ID TEAM_ABBREVIATION               TEAM_NAME  \
# 0         22022  1610612746               LAC             LA Clippers
# 1         22022  1610612749               MIL         Milwaukee Bucks
# 2         22022  1610612745               HOU         Houston Rockets
# 3         22022  1610612737               ATL           Atlanta Hawks
# 4         22022  1610612760               OKC   Oklahoma City Thunder
# ...         ...         ...               ...                     ...
# 17155     22016  1610612757               POR  Portland Trail Blazers
# 17156     22016  1610612743               DEN          Denver Nuggets
# 17157     22016  1610612758               SAC        Sacramento Kings
# 17158     22016  1610612752               NYK         New York Knicks
# 17159     22016  1610612764               WAS      Washington Wizards
#
#           GAME_ID   GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  \
# 0      0022200203  2022-11-14    LAC @ HOU  W  240  122  ...   0.788     9
# 1      0022200204  2022-11-14  MIL vs. ATL  L  240  106  ...   0.780    11
# 2      0022200203  2022-11-14  HOU vs. LAC  L  241  106  ...   0.613    10
# 3      0022200204  2022-11-14    ATL @ MIL  W  240  121  ...   0.867    13
# 4      0022200201  2022-11-14    OKC @ BOS  L  239  122  ...   0.810    10
# ...           ...         ...          ... ..  ...  ...  ...     ...   ...
# 17155  0021600728  2017-01-31  POR vs. CHA  W  240  115  ...   0.870    11
# 17156  0021600729  2017-01-31    DEN @ LAL  L  240  116  ...   0.826    20
# 17157  0021600726  2017-01-31    SAC @ HOU  L  240   83  ...   0.577    10
# 17158  0021600724  2017-01-31    NYK @ WAS  L  241  101  ...   0.800    22
# 17159  0021600724  2017-01-31  WAS vs. NYK  W  239  117  ...   0.800     9
#
#        DREB  REB  AST  STL  BLK  TOV  PF  PLUS_MINUS
# 0        35   44   25    6    4   16  23        16.0
# 1        35   46   21    4    3   15  26       -15.0
# 2        30   40   20   11    3   14  22       -16.0
# 3        32   45   23    4    4    9  23        15.0
# 4        41   51   21    4    6   19  21        -4.0
# ...     ...  ...  ...  ...  ...  ...  ..         ...
# 17155    40   51   23    8    2    8  18        17.0
# 17156    31   51   26   12    5   11  18        -4.0
# 17157    35   45   22    9    7   11  17       -22.0
# 17158    29   51   18    8    2   12  17       -16.0
# 17159    37   46   27    4    4   12  25        16.0
#
# [17160 rows x 28 columns]

# %%
df = df.drop(['TEAM_ID', 'PTS', 'TEAM_NAME', 'SEASON_ID', 'GAME_ID' \
              , 'GAME_DATE', 'PLUS_MINUS'], axis = 1)
df
# Out:
#       TEAM_ABBREVIATION      MATCHUP WL  MIN  FGM  FGA  FG_PCT  FG3M  FG3A  \
# 0                   LAC    LAC @ HOU  W  240   41   81   0.506    14    38
# 1                   MIL  MIL vs. ATL  L  240   34   82   0.415     6    29
# 2                   HOU  HOU vs. LAC  L  241   39   86   0.453     9    30
# 3                   ATL    ATL @ MIL  W  240   44   92   0.478     7    20
# 4                   OKC    OKC @ BOS  L  239   47   98   0.480    11    30
# ...                 ...          ... ..  ...  ...  ...     ...   ...   ...
# 17155               POR  POR vs. CHA  W  240   42   93   0.452    11    31
# 17156               DEN    DEN @ LAL  L  240   41   99   0.414    15    27
# 17157               SAC    SAC @ HOU  L  240   30   86   0.349     8    29
# 17158               NYK    NYK @ WAS  L  241   34   93   0.366     5    24
# 17159               WAS  WAS vs. NYK  W  239   49   88   0.557     7    22
#
#        FG3_PCT  ...  FTA  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF
# 0        0.368  ...   33   0.788     9    35   44   25    6    4   16  23
# 1        0.207  ...   41   0.780    11    35   46   21    4    3   15  26
# 2        0.300  ...   31   0.613    10    30   40   20   11    3   14  22
# 3        0.350  ...   30   0.867    13    32   45   23    4    4    9  23
# 4        0.367  ...   21   0.810    10    41   51   21    4    6   19  21
# ...        ...  ...  ...     ...   ...   ...  ...  ...  ...  ...  ...  ..
# 17155    0.355  ...   23   0.870    11    40   51   23    8    2    8  18
# 17156    0.556  ...   23   0.826    20    31   51   26   12    5   11  18
# 17157    0.276  ...   26   0.577    10    35   45   22    9    7   11  17
# 17158    0.208  ...   35   0.800    22    29   51   18    8    2   12  17
# 17159    0.318  ...   15   0.800     9    37   46   27    4    4   12  25
#
# [17160 rows x 21 columns]

# %%
appDummies = pd.get_dummies(df)
appDummies = appDummies.dropna()
appDummies
# Out:
#        MIN  FGM  FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  ...  \
# 0      240   41   81   0.506    14    38    0.368   26   33   0.788  ...
# 1      240   34   82   0.415     6    29    0.207   32   41   0.780  ...
# 2      241   39   86   0.453     9    30    0.300   19   31   0.613  ...
# 3      240   44   92   0.478     7    20    0.350   26   30   0.867  ...
# 4      239   47   98   0.480    11    30    0.367   17   21   0.810  ...
# ...    ...  ...  ...     ...   ...   ...      ...  ...  ...     ...  ...
# 17155  240   42   93   0.452    11    31    0.355   20   23   0.870  ...
# 17156  240   41   99   0.414    15    27    0.556   19   23   0.826  ...
# 17157  240   30   86   0.349     8    29    0.276   15   26   0.577  ...
# 17158  241   34   93   0.366     5    24    0.208   28   35   0.800  ...
# 17159  239   49   88   0.557     7    22    0.318   12   15   0.800  ...
#
#        MATCHUP_WAS vs. PHX  MATCHUP_WAS vs. POR  MATCHUP_WAS vs. SAC  \
# 0                        0                    0                    0
# 1                        0                    0                    0
# 2                        0                    0                    0
# 3                        0                    0                    0
# 4                        0                    0                    0
# ...                    ...                  ...                  ...
# 17155                    0                    0                    0
# 17156                    0                    0                    0
# 17157                    0                    0                    0
# 17158                    0                    0                    0
# 17159                    0                    0                    0
#
#        MATCHUP_WAS vs. SAN  MATCHUP_WAS vs. SAS  MATCHUP_WAS vs. SEA  \
# 0                        0                    0                    0
# 1                        0                    0                    0
# 2                        0                    0                    0
# 3                        0                    0                    0
# 4                        0                    0                    0
# ...                    ...                  ...                  ...
# 17155                    0                    0                    0
# 17156                    0                    0                    0
# 17157                    0                    0                    0
# 17158                    0                    0                    0
# 17159                    0                    0                    0
#
#        MATCHUP_WAS vs. TOR  MATCHUP_WAS vs. UTA  WL_L  WL_W
# 0                        0                    0     0     1
# 1                        0                    0     1     0
# 2                        0                    0     1     0
# 3                        0                    0     0     1
# 4                        0                    0     1     0
# ...                    ...                  ...   ...   ...
# 17155                    0                    0     0     1
# 17156                    0                    0     1     0
# 17157                    0                    0     1     0
# 17158                    0                    0     1     0
# 17159                    0                    0     0     1
#
# [17151 rows x 1922 columns]

# %%
y = appDummies['WL_W'].values
x = appDummies.drop(['WL_W', 'WL_L'], axis = 1)

# %%
from sklearn.model_selection import train_test_split
# Split the data into X_train, X_test, y_train, y_test
xTrain, xTest, yTrain, yTest = train_test_split(x, y, random_state=1)

# Scale the Data
scaler = StandardScaler().fit(xTrain)
xTrainScaled = scaler.transform(xTrain)
xTestScaled = scaler.transform(xTest)

# %%
# Create a logistic regression model
classifier = LogisticRegression()

# %%
# fit Logistic Regression
classifier.fit(xTrain, yTrain)

# Print Scores
print('Logistic Regression')
print(f'Training Score: {classifier.score(xTrain, yTrain)}')
print(f'Testing Score: {classifier.score(xTest, yTest)}')
print(f'Scaled Training Score: {classifier.score(xTrainScaled, yTrain)}')
print(f'Scaled Testing Score: {classifier.score(xTestScaled, yTest)}')
# Out:
# Logistic Regression
# Training Score: 0.8534556479825857
# Testing Score: 0.8435167910447762
# Scaled Training Score: 0.6668739796315012
# Scaled Testing Score: 0.6168376865671642
# C:\Users\johnm\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Create Random Forest Model
clf = RandomForestClassifier(random_state=42, n_estimators=500)

# %%
# fit Random Forest Model
clf.fit(xTrain, yTrain)

# Print Scores
print('Random Forest Classifier')
print(f'Training Score: {clf.score(xTrain, yTrain)}')
print(f'Testing Score: {clf.score(xTest, yTest)}')
print(f'Scaled Training Score: {clf.score(xTrainScaled, yTrain)}')
print(f'Scaled Testing Score: {clf.score(xTestScaled, yTest)}')
# Out:
# Random Forest Classifier
# Training Score: 1.0
# Testing Score: 0.8108675373134329
# Scaled Training Score: 0.5032263080152375
# Scaled Testing Score: 0.49953358208955223

# %%
import tensorflow as tf
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features = len(xTrain.columns)
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=80, activation='relu', input_dim=input_features))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=30, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 80)                153680
#
#  dense_4 (Dense)             (None, 30)                2430
#
#  dense_5 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 156,141
# Trainable params: 156,141
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Create a callback that saves the model's weights every five epochs
# Import checkpoint dependencies
import os
from tensorflow.keras.callbacks import ModelCheckpoint

# Define checkpoints variables
os.makedirs('checkpoints/', exist_ok=True)
checkpoint_path= 'checkpoints/weights.{epoch}.hdf5'

# Create callback 
Callback = ModelCheckpoint(filepath=checkpoint_path,
                              verbose=1,
                              save_weights_only=True,
                              save_freq='epoch',
                              period=5)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# Train the model
fitModel = nn.fit(xTrainScaled, yTrain, epochs=100,callbacks=[Callback])
# Out:
# Epoch 1/100
# 402/402 [==============================] - 1s 1ms/step - loss: 0.5919 - accuracy: 0.6869
# Epoch 2/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.4200 - accuracy: 0.8007
# Epoch 3/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.3571 - accuracy: 0.8295
# Epoch 4/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.3211 - accuracy: 0.8442
# Epoch 5/100
# 387/402 [===========================>..] - ETA: 0s - loss: 0.2900 - accuracy: 0.8560
# Epoch 5: saving model to checkpoints\weights.5.hdf5
# 402/402 [==============================] - 0s 1ms/step - loss: 0.2912 - accuracy: 0.8559
# Epoch 6/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.2603 - accuracy: 0.8699
# Epoch 7/100
# 402/402 [==============================] - 1s 1ms/step - loss: 0.2333 - accuracy: 0.8835
# Epoch 8/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.2043 - accuracy: 0.8970
# Epoch 9/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.1768 - accuracy: 0.9128
# Epoch 10/100
# 388/402 [===========================>..] - ETA: 0s - loss: 0.1472 - accuracy: 0.9306
# Epoch 10: saving model to checkpoints\weights.10.hdf5
# 402/402 [==============================] - 0s 1ms/step - loss: 0.1477 - accuracy: 0.9304
# Epoch 11/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.1255 - accuracy: 0.9410
# Epoch 12/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0999 - accuracy: 0.9540
# Epoch 13/100
# 402/402 [==============================] - 1s 1ms/step - loss: 0.0834 - accuracy: 0.9628
# Epoch 14/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0649 - accuracy: 0.9714
# Epoch 15/100
# 385/402 [===========================>..] - ETA: 0s - loss: 0.0522 - accuracy: 0.9778
# Epoch 15: saving model to checkpoints\weights.15.hdf5
# 402/402 [==============================] - 1s 1ms/step - loss: 0.0530 - accuracy: 0.9776
# Epoch 16/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0447 - accuracy: 0.9817
# Epoch 17/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0372 - accuracy: 0.9850
# Epoch 18/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0296 - accuracy: 0.9883
# Epoch 19/100
# 402/402 [==============================] - 0s 995us/step - loss: 0.0239 - accuracy: 0.9904
# Epoch 20/100
# 402/402 [==============================] - ETA: 0s - loss: 0.0197 - accuracy: 0.9926
# Epoch 20: saving model to checkpoints\weights.20.hdf5
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0197 - accuracy: 0.9926
# Epoch 21/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0174 - accuracy: 0.9932
# Epoch 22/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0135 - accuracy: 0.9945
# Epoch 23/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0151 - accuracy: 0.9940
# Epoch 24/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0125 - accuracy: 0.9953
# Epoch 25/100
# 357/402 [=========================>....] - ETA: 0s - loss: 0.0135 - accuracy: 0.9958
# Epoch 25: saving model to checkpoints\weights.25.hdf5
# 402/402 [==============================] - 1s 1ms/step - loss: 0.0138 - accuracy: 0.9957
# Epoch 26/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0152 - accuracy: 0.9949
# Epoch 27/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0159 - accuracy: 0.9946
# Epoch 28/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0149 - accuracy: 0.9956
# Epoch 29/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0105 - accuracy: 0.9970
# Epoch 30/100
# 358/402 [=========================>....] - ETA: 0s - loss: 0.0090 - accuracy: 0.9973
# Epoch 30: saving model to checkpoints\weights.30.hdf5
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0087 - accuracy: 0.9974
# Epoch 31/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0098 - accuracy: 0.9970
# Epoch 32/100
# 402/402 [==============================] - 0s 1000us/step - loss: 0.0069 - accuracy: 0.9975
# Epoch 33/100
# 402/402 [==============================] - 0s 976us/step - loss: 0.0105 - accuracy: 0.9962
# Epoch 34/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0091 - accuracy: 0.9972
# Epoch 35/100
# 353/402 [=========================>....] - ETA: 0s - loss: 0.0098 - accuracy: 0.9967
# Epoch 35: saving model to checkpoints\weights.35.hdf5
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0103 - accuracy: 0.9965
# Epoch 36/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0091 - accuracy: 0.9973
# Epoch 37/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0050 - accuracy: 0.9984
# Epoch 38/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0054 - accuracy: 0.9984
# Epoch 39/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0048 - accuracy: 0.9984
# Epoch 40/100
# 398/402 [============================>.] - ETA: 0s - loss: 0.0037 - accuracy: 0.9987
# Epoch 40: saving model to checkpoints\weights.40.hdf5
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0037 - accuracy: 0.9987
# Epoch 41/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0056 - accuracy: 0.9984
# Epoch 42/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0047 - accuracy: 0.9984
# Epoch 43/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0082 - accuracy: 0.9974
# Epoch 44/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0052 - accuracy: 0.9983
# Epoch 45/100
# 395/402 [============================>.] - ETA: 0s - loss: 0.0057 - accuracy: 0.9979
# Epoch 45: saving model to checkpoints\weights.45.hdf5
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0056 - accuracy: 0.9980
# Epoch 46/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0022 - accuracy: 0.9992
# Epoch 47/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0013 - accuracy: 0.9996
# Epoch 48/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0035 - accuracy: 0.9989
# Epoch 49/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0029 - accuracy: 0.9990
# Epoch 50/100
# 395/402 [============================>.] - ETA: 0s - loss: 0.0035 - accuracy: 0.9990
# Epoch 50: saving model to checkpoints\weights.50.hdf5
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0035 - accuracy: 0.9990
# Epoch 51/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0056 - accuracy: 0.9978
# Epoch 52/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0085 - accuracy: 0.9975
# Epoch 53/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0065 - accuracy: 0.9975
# Epoch 54/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0032 - accuracy: 0.9990
# Epoch 55/100
# 400/402 [============================>.] - ETA: 0s - loss: 0.0054 - accuracy: 0.9988
# Epoch 55: saving model to checkpoints\weights.55.hdf5
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0054 - accuracy: 0.9988
# Epoch 56/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0013 - accuracy: 0.9996
# Epoch 57/100
# 402/402 [==============================] - 0s 1ms/step - loss: 5.6923e-04 - accuracy: 0.9997
# Epoch 58/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0011 - accuracy: 0.9998
# Epoch 59/100
# 402/402 [==============================] - 0s 1ms/step - loss: 2.4602e-04 - accuracy: 1.0000
# Epoch 60/100
# 401/402 [============================>.] - ETA: 0s - loss: 2.2928e-04 - accuracy: 0.9998
# Epoch 60: saving model to checkpoints\weights.60.hdf5
# 402/402 [==============================] - 0s 1ms/step - loss: 2.2914e-04 - accuracy: 0.9998
# Epoch 61/100
# 402/402 [==============================] - 0s 1ms/step - loss: 7.3244e-04 - accuracy: 0.9998
# Epoch 62/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0058 - accuracy: 0.9984
# Epoch 63/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0096 - accuracy: 0.9970
# Epoch 64/100
# 402/402 [==============================] - 0s 998us/step - loss: 0.0067 - accuracy: 0.9981
# Epoch 65/100
# 386/402 [===========================>..] - ETA: 0s - loss: 0.0050 - accuracy: 0.9985
# Epoch 65: saving model to checkpoints\weights.65.hdf5
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0049 - accuracy: 0.9986
# Epoch 66/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0023 - accuracy: 0.9992
# Epoch 67/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0016 - accuracy: 0.9998
# Epoch 68/100
# 402/402 [==============================] - 0s 1ms/step - loss: 9.4260e-04 - accuracy: 0.9998
# Epoch 69/100
# 402/402 [==============================] - 0s 980us/step - loss: 3.9840e-04 - accuracy: 0.9999
# Epoch 70/100
# 357/402 [=========================>....] - ETA: 0s - loss: 4.6536e-04 - accuracy: 0.9999
# Epoch 70: saving model to checkpoints\weights.70.hdf5
# 402/402 [==============================] - 0s 1ms/step - loss: 4.2220e-04 - accuracy: 0.9999
# Epoch 71/100
# 402/402 [==============================] - 0s 1ms/step - loss: 5.8227e-04 - accuracy: 0.9997
# Epoch 72/100
# 402/402 [==============================] - 0s 991us/step - loss: 1.3999e-04 - accuracy: 1.0000
# Epoch 73/100
# 402/402 [==============================] - 0s 1ms/step - loss: 8.5076e-05 - accuracy: 1.0000
# Epoch 74/100
# 402/402 [==============================] - 0s 1ms/step - loss: 1.4847e-04 - accuracy: 1.0000
# Epoch 75/100
# 380/402 [===========================>..] - ETA: 0s - loss: 0.0058 - accuracy: 0.9979
# Epoch 75: saving model to checkpoints\weights.75.hdf5
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0065 - accuracy: 0.9977
# Epoch 76/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0091 - accuracy: 0.9975
# Epoch 77/100
# 402/402 [==============================] - 0s 993us/step - loss: 0.0041 - accuracy: 0.9981
# Epoch 78/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0026 - accuracy: 0.9995
# Epoch 79/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0011 - accuracy: 0.9998
# Epoch 80/100
# 381/402 [===========================>..] - ETA: 0s - loss: 3.4706e-04 - accuracy: 0.9999
# Epoch 80: saving model to checkpoints\weights.80.hdf5
# 402/402 [==============================] - 0s 1ms/step - loss: 3.3963e-04 - accuracy: 0.9999
# Epoch 81/100
# 402/402 [==============================] - 0s 1ms/step - loss: 2.3719e-04 - accuracy: 0.9999
# Epoch 82/100
# 402/402 [==============================] - 0s 1ms/step - loss: 1.2414e-04 - accuracy: 1.0000
# Epoch 83/100
# 402/402 [==============================] - 0s 985us/step - loss: 3.7531e-04 - accuracy: 0.9998
# Epoch 84/100
# 402/402 [==============================] - 0s 989us/step - loss: 5.6379e-04 - accuracy: 0.9998
# Epoch 85/100
# 396/402 [============================>.] - ETA: 0s - loss: 1.9355e-04 - accuracy: 1.0000
# Epoch 85: saving model to checkpoints\weights.85.hdf5
# 402/402 [==============================] - 0s 1ms/step - loss: 1.9133e-04 - accuracy: 1.0000
# Epoch 86/100
# 402/402 [==============================] - 0s 1ms/step - loss: 2.7304e-04 - accuracy: 0.9998
# Epoch 87/100
# 402/402 [==============================] - 0s 1ms/step - loss: 7.6641e-04 - accuracy: 0.9998
# Epoch 88/100
# 402/402 [==============================] - 0s 991us/step - loss: 0.0046 - accuracy: 0.9988
# Epoch 89/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0055 - accuracy: 0.9984
# Epoch 90/100
# 358/402 [=========================>....] - ETA: 0s - loss: 0.0052 - accuracy: 0.9988
# Epoch 90: saving model to checkpoints\weights.90.hdf5
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0056 - accuracy: 0.9985
# Epoch 91/100
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0039 - accuracy: 0.9984
# Epoch 92/100
# 402/402 [==============================] - 0s 1ms/step - loss: 9.6879e-04 - accuracy: 0.9998
# Epoch 93/100
# 402/402 [==============================] - 0s 999us/step - loss: 0.0013 - accuracy: 0.9998
# Epoch 94/100
# 402/402 [==============================] - 0s 1ms/step - loss: 1.7882e-04 - accuracy: 0.9999
# Epoch 95/100
# 398/402 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9999
# Epoch 95: saving model to checkpoints\weights.95.hdf5
# 402/402 [==============================] - 0s 1ms/step - loss: 0.0013 - accuracy: 0.9999
# Epoch 96/100
# 402/402 [==============================] - 0s 1ms/step - loss: 7.3941e-05 - accuracy: 1.0000
# Epoch 97/100
# 402/402 [==============================] - 0s 982us/step - loss: 4.6132e-05 - accuracy: 1.0000
# Epoch 98/100
# 402/402 [==============================] - 0s 1ms/step - loss: 1.1735e-04 - accuracy: 0.9999
# Epoch 99/100
# 402/402 [==============================] - 1s 1ms/step - loss: 9.6610e-05 - accuracy: 0.9999
# Epoch 100/100
# 394/402 [============================>.] - ETA: 0s - loss: 3.2860e-05 - accuracy: 1.0000
# Epoch 100: saving model to checkpoints\weights.100.hdf5
# 402/402 [==============================] - 0s 1ms/step - loss: 3.2371e-05 - accuracy: 1.0000

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(xTestScaled,yTest,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 134/134 - 0s - loss: 2.6400 - accuracy: 0.7785 - 174ms/epoch - 1ms/step
# Loss: 2.6399855613708496, Accuracy: 0.7784515023231506
